# %% [markdown]
# # Week 4 Day 1, Core: More Memoization

# %%
def check_test(actual, expected):
    if expected != actual:
        print(f"Function should return the value {expected}, it is returning the value {actual}")
    else:
        print(f"Congratulations, the test case passed!")

# %% [markdown]
# ## 1. Unique Paths in a Grid
#
# You are given a grid of size m x n. Count how many ways there are of getting from the top-left hand corner to the bottom-right hand corner by only moving right or down.
#
# *For example*, if you have a `3x2` grid:
#
# *Path 1:*
# ![path1.jpg](attachment:path1.jpg)
#
# *Path 2:*
# ![path2.jpg](attachment:path2.jpg)
#
# *Path 3:*
# ![path3.jpg](attachment:path3.jpg)
#
# There are 3 total unique paths for a `3x2` grid.
#
# ### 1.1
# Write a recursive function `paths(m, n)` that takes two integers `m` and `n` and returns the number of number of paths from the top-left corner to the bottom-right corner in an `m x n` grid.<br/> <br/>
#
# <details>
#     <summary><i>Give me a Hint</i></summary>
# Think of your base case carefully. What is $paths(m,1)$? What is $paths(1,n)$?
# </details>

# %%
def paths(m, n):
    pass

# %% [markdown]
# ## Check your answer here

# %%
check_test(paths(10,3), 55)
check_test(paths(10,2), 10)
check_test(paths(10,1), 1)
check_test(paths(3,5), 15)
check_test(paths(1,4), 1)

# %% [markdown]
# ### 1.2
# We're going to create a list of lists called `mem` such that : <br/><br/>
# $$
# mem[i][j] =
# \begin{cases}
# -1 \text{  if } paths_{i,j}  \text{ has not been computed before}\\
# paths_{i,j} \text{ if it has}
# \end{cases}
# $$

# %% [markdown]
# Write a function `create_memory(r, c)` that takes two integers `r` and `c` and returns a list of lists with `r` rows and `c` colums, where each element is `-1`.
# <br/><br/>
# <details>
#     <summary><i>Give me a Hint</i></summary>
# Make sure each created lists are not referencing to the same list
# </details>

# %%
def create_memory(r, c):
    pass

# %% [markdown]
# ### 1.3
# Write a function `memo_paths(m, n, mem)` that takes two integers `m`, `n` and a list of lists `mem` and that returns $paths(m,n)$.

# %%
def memo_paths(m, n, mem):
    pass

# %% [markdown]
# ### 1.4
# Write a function `unique_paths(m, n)` that returns $paths(m,n)$. It should use `create_memory(r, c)` and `memo_paths(m, n, mem)`.

# %%
def unique_paths(m, n):
    pass

# %% [markdown]
# # Check your answer here

# %%
check_test(unique_paths(10,3), 55)
check_test(unique_paths(10,2), 10)
check_test(unique_paths(10,1), 1)
check_test(unique_paths(3,5), 15)
check_test(unique_paths(1,4), 1)

# %% [markdown]
# ## 2. Min Number of Ways to Make Change
#
# Suppose you live in a country whose coin denominations are in the list ```L```. For example, in Ethiopia we would have ```L = [1,5,10,50,100,200]```, but other countries have different coin systems. Implement a function ```makeChange(n, L)``` which returns the minimum number of coins needed to make change for ```n``` cents using the coins in ```L```.
#
# *For example*, ```makeChange(14, [1,5,10,50,100,200])``` should return ```5```, since you can make change for ```14``` cents by giving one ```10``` cent piece and four ```1``` cent pieces, for a total of ```5``` coins (you could also give two ```5``` cent pieces and four ```1``` cent pieces, or ```14``` ```1``` cent pieces, but those options would each require more coins). If it is impossible to make change for ```n``` cents using ```L```, you should return ```-1```. For example, ```makeChange(3, [2, 5])``` should return ```-1``` since there is no way to make change for ```3``` cents using ```2``` cent and ```5``` cent pieces.
#
# ### 2.1
# First implement a function ```makeChange``` that takes as input an integer $n$ and a list $L$ (with coin values sorted in increasing order) and returns the minimum number of ways to make change using plain recursion.

# %%
def make_change(n, L):
    pass

# %% [markdown]
# ## Check your answer here

# %%
check_test(make_change(14, [1,5,10,25,50,100]), 5)
check_test(make_change(12,[1,4,6,8,10,12]), 1)
check_test(make_change(11,[4,6,8]), -1)

# %% [markdown]
# ### 2.2
# Implement a faster version or your solution using memoization in `makeChange_memo(n, L)`.

# %%
def make_change_memo(n, L):
    pass

# %% [markdown]
# ## Check your answer here

# %%
check_test(make_change_memo(14, [1,5,10,25,50,100]), 5)
check_test(make_change_memo(50,[1,4,6,8,10,12]), 5)
check_test(make_change_memo(11,[4,6,8]), -1)
